# %% [markdown]
# # SDSU Training Astronomy Research Scholars (STARS)
# # Day 7: Spectral Types Expedition
#
#
# ### Adapted from:
#  - [SDSS Voyages Spectral Types Expedition](http://voyages.sdss.org/expeditions/expedition-to-the-milky-way/spectral-types/)
#
# ### Prof. Kate Rubin <br> July 5, 2023

# %% [markdown]
# We've already seen that stars with different colors have different temperatures.  By analyzing the thermal spectrum of a star to find its peak wavelength, you can calculate the star's temperature.
#
# However, you might have wondered what happens when a star’s peak wavelength does not fall within the spectral range of your instrument. For a very hot star, the peak wavelength may be well into the ultraviolet wavelength range. For a very cool star, the peak wavelength may be well into the infrared. Do astronomers have other ways to find the temperature of a star from its spectrum, even if the star’s peak wavelength is too short or too long to show up?
#
# Fortunately, the answer is "yes"!

# %% [markdown]
# ## Spectral Peaks and Valleys
#
# If thermal radiation were the only source of light from a star, the star’s spectrum would be a nice smooth curve. However, actual spectra observed from stars have a series of peaks and valleys as shown in the spectrum below, meaning some of their light comes from “non-thermal” radiation – light emitted or absorbed by a process other than random jostling of atoms.
#
# The spectrum below, from the SDSS spectral database, is a typical example of the spectrum of a star:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Many of these peaks and valleys have labels on them. You may recognize some of these labels as the symbols of chemical elements.
#
# Every star has a unique pattern of peaks and valleys, and these patterns can be grouped into “spectral types” of stars. The traditional spectral types are denoted by the letters O,B,A,F,G,K,M.  (Some new spectral types have also been added in the last few years.)
#
# Before you find out what these letters mean, take a shot at developing your own system for classifying stars based on their spectra.

# %% [markdown]
# Pretend for a moment that you are an astronomer living in the early 20th century, before the OBAFGKM star classification system was developed. You are one of the first astronomers who ever looked at spectra of stars, and it is up to you to develop a classification system.
#
# **Packet 1** contains several printouts of the spectra of stars observed by the SDSS. Look at their spectra and divide them into several groups. There is no set number of groups you should try to achieve, and the groups do not have to have equal numbers of stars (because not all types of stars are equally common). If you find a spectrum that has nothing in common with any of the others, a group of one is OK (but on the other hand, 14 groups of one is probably not useful either).

# %% [markdown]
# **Exercise 1.**  Make a table that summarizes your classification system.  Your table should contain at least three columns: one that lists the name of each class; one that lists the stars within each class (by their plate-fiber ID numbers); and one that describes the most important characteristics defining each class.  Be sufficiently specific that another group could use your descriptions to duplicate your classifications.

# %% [markdown]
# Now, find another group and partner up with them.  Compare your classification system to theirs.

# %% [markdown]
# **Question 1A.** Do you have the same number of spectral types as the other group does?  If not, what distinctions did one group draw that the other group did not?

# %% [markdown]
# **Question 1B.**  What do your classification systems have in common?  What makes them different?

# %% [markdown]
# **Question 1C.** Try to combine the best features of each classification system.  Repeat Exercise 1 with your improved system.

# %% [markdown]
# You have just solved the same problem astronomers at the turn of the century faced when they developed the technology to take spectra of stars. If your classification system is different from the modern one, don’t worry. The original classification system underwent several revisions before astronomers arrived at a consensus. Originally, the classifications were the letters A through P. As time progressed, some classifications were added, some were dropped, and some were combined.

# %% [markdown]
# ## Absorption and Emission Lines

# %% [markdown]
# Now we can start making the connection between the peaks and valleys we see in a star’s spectrum and the energy levels of the star’s atoms. Let’s say that I shine a continuous light source through a cloud of hydrogen gas. Not all of the light will make it through. All the photons that have exactly 10.2 eV of energy will not make it through the hydrogen, because they will be absorbed by hydrogen atoms jumping from the first energy level to the second energy level. Likewise, no light with an energy of 1.89 eV will make it through; those photons will be absorbed by hydrogen atoms jumping from the second energy level to the third energy level. The light that the hydrogen cloud absorbs shows up as dips in the cloud’s spectrum.  (Recall also that it's absorption transitions from the second energy level to higher energy levels in the hydrogen atom that fall in the optical wavelength range.)
#
# If the cloud is too hot, however, all its hydrogen atoms will crash into each other with enough force to free their electrons, and the gas will become ionized. The hot cloud’s hydrogen ions have no electrons, so they cannot absorb light. When you look at the hot cloud’s spectrum, you will not see any valleys from hydrogen absorption lines. Ionization occurs at about 10,000 K for hydrogen. Therefore, if you do not see hydrogen lines in the hot cloud’s spectrum, you can conclude it is hotter than 10,000 K.
#
# However, if the cloud is too cool, then all of the electrons in the hydrogen atoms will just be sitting in the ground state -- there won't be any sitting around in the second energy level, and so they won't be able to absorb the wavelengths that correspond to transitions that start at this level. In this case, you also would not see any hydrogen lines in an optical spectrum of the cloud. You would see the strongest optical hydrogen lines for a cloud that is at about 9000 K.
#
# If you saw a cloud whose spectrum showed no hydrogen lines, how would you tell if it were hot or cool? For a cloud of pure hydrogen, you couldn’t. But for real stars, which contain atoms of many elements besides hydrogen, you could look at the absorption and emission lines of other elements.

# %% [markdown]
# ## Absorption Lines in Real Stars

# %% [markdown]
# For most elements, there is a certain temperature at which their absorption lines are strongest. The lines you see in a star’s spectrum act like thermometers. Some compounds, like titanium oxide, only appear in the spectra of very cool stars. Others, like helium, appear only in the spectra of very hot stars.
#
# Therefore, the sequence of spectral types, OBAFGKM, is actually a temperature sequence with O representing the hottest stars and M representing the coolest stars.
#
# Astronomers have come up with several different mneumonic devices to remember this sequence, many of which I find to be problematic in today's context.  Feel free to invent your own!
#
# The table below shows some of the characteristic absorption lines of each spectral type.

# %% [markdown]
# |Spectral Type | Temperature (Kelvin) | Spectral Lines |
# |--------------|----------------------|----------------|
# | O	| 28,000 – 50,000 |	Ionized helium and metals, weak hydrogen |
# | B	| 10,000 – 28,000 |	Neutral helium, ionized metals, some hydrogen |
# | A	| 7,500 – 10,000  |	Strong hydrogen, some singly-ionized metals |
# | F	| 6,000 – 7,500	  | Hydrogen weaker, ionized calcium (labeled H and K on spectra) and iron, some neutral metals |
# | G	| 5,000 – 6,000	  | Neutral and ionized metals, especially calcium; strong G band, weak hydrogen |
# | K	| 3,500 – 5,000	  | Neutral metals, sodium, titanium oxide begins to appear |
# | M	| 2,500 – 3,500	  | Strong titanium oxide, very strong sodium |

# %% [markdown]
# You may not know where all of these elements have their absorption/emission lines. The chart below lists some of the more common ones and their approximate location in the electromagnetic spectrum.

# %% [markdown]
# | Spectral Lines |	Wavelengths (Angstroms) |
# |----------------|--------------------------|
# |H$\alpha$, H$\beta$, H$\gamma$ | 6564, 4861, 4350 |
# | Ionized Calcium H and K Lines |	3800 – 4000    |
# | Titanium Oxide	            | lots of lines from 4900 – 5200, 5400 – 5700, 6200 – 6300, 6700 – 6900 |
# |G Band	                        |  4250 |
# | Sodium	|                      5890 |
# | Helium (neutral)	| 4200 |
# | Helium (ionized)	| 4400 |

# %% [markdown]
# **Question 2A.**  How does your classification system compare to the OBAFGKM spectral type classification shown above? What are the similarities? What are the differences?

# %% [markdown]
# Now take a look at the spectrum you saw earlier:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Question 2B.** What lines are present in this spectrum? Do you see any spectral lines of ionized atoms?

# %% [markdown]
# **Question 2C.** What is the spectral type of this star?

# %% [markdown]
# **Question 2D.** Check your answer using Wein's Law (i.e., the relationship between the peak wavelength of the star's spectrum and its temperature).  Is this temperature consistent with the spectral type you identified above?

# %% [markdown]
# The peak wavelength is not always in the portion of the spectrum we observe, however. The spectra taken by the SDSS do not cover the entire electromagnetic spectrum. If a star has a peak wavelength in the ultraviolet (blueward of 4,000 Angstroms) or in the infrared (beyond 10,000 Angstroms), you cannot see the peak. However, you will still be able to see spectral lines for the star, so you can still use the OBAFGKM spectral type classification to find the star’s approximate temperature.

# %% [markdown]
# **Exercise 3.** Examine the stellar spectra contained in **Packet 2**, and determine the spectral type of each star.  Record your results.

# %% [markdown]
# **Exercise 4.** On the board, make a histogram showing your results from Exercise 3 so that you can share them with the other groups. Let the bins represent the spectral types (OBAFGKM). Label each square with the star's plate number and fiber number.  Then, compare your results to those from the other groups.  Are there stars that you disagree about?  If so, what is the source of this disagreement?

# %% [markdown]
# **Question 4A.** Which types of stars are the most common in your histograms?  Which types of stars are the least common?

# %% [markdown]
# **Question 4B.**  You may have noticed that type O stars are rare.  Why do you think we see so few of them?

# %% [markdown]
# **Question 4C.** Did you find any stars that did not fit into any spectral types?  If so, what where their characteristics?
